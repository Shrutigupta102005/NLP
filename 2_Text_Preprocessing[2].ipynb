# %% [markdown]
# #2. TEXT PREPROCESSING

# %% [markdown]
# #a. BASIC CLEANING
#
# **i. HTML Tag Removal**

# %%
text1 = "<p>The <b>movie</b> was <i>fantastic</i> and <a href='#'>enjoyable</a>.</p>"

# %%
import re #using RegEx
def remove_html_tags(text):
    pattern=re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
remove_html_tags(text1)
# Out:
# 'The movie was fantastic and enjoyable.'

# %% [markdown]
# **ii. URL Removal**

# %%
text2="Check out the data at https://www.kaggle.com/code/anushkashukla1/notebooka7af49852a/edit"
text3="Google search here at www.google.com"
text4="For notebook click https://github.com/theinfoflux/Real-Time-Object-Detection-with-ESP32-CAM-OpenCV to search www.google.com"

# %%
import re
def remove_url(text):
    pattern=re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
remove_url(text4)
# Out:
# 'For notebook click  to search '

# %% [markdown]
# **iii. Remove Punctuation**

# %%
import string, time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude=string.punctuation

# %%
def remove_punc(text):
    for char in exclude:
        text=text.replace(char,'')
    return text

# %%
text5='remove. with. Punctuation?'

# %%
print(remove_punc(text5))
# Out:
# remove with Punctuation

# %% [markdown]
# **iv. Basic Spell Check**

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
incorrect_text='thhis is noot justifid, since it wll be considred as a misake'
textBlb=TextBlob(incorrect_text)
textBlb.correct().string
# Out:
# 'this is not justified, since it all be considered as a mistake'

# %% [markdown]
# **v. Handling Emojis**: Unicode Normalization

# %%
emoji_text="Hey this is to convert emoji into a machine understandable format. Here is the 😊, please convert it."

# %%
emoji_text
# Out:
# 'Hey this is to convert emoji into a machine understandable format. Here is the 😊, please convert it.'

# %%
emoji_text.encode("utf-8")
# Out:
# b'Hey this is to convert emoji into a machine understandable format. Here is the \xf0\x9f\x98\x8a, please convert it.'

# %% [markdown]
# #b. BASIC PREPROCESSING
#
# **i. Lowercasing**

# %%
text_clean = "The Movie Was Absolutely Fantastic and Enjoyable!"

# %%
def lowercase_text(text):
    return text.lower()

# %%
lowercase_text(text_clean)
# Out:
# 'the movie was absolutely fantastic and enjoyable!'

# %% [markdown]
# **ii. Tokenization**
#
#
# 1.   Split function
# 2.   RegEx
# 3.   NLTK
#
#      i.   Word Tokenization
#
#      ii.   Sentence Tokenization
# 4. SPACY (best)

# %% [markdown]
# **1. Split Function**

# %%
#word tokenization
sent1='Hey I am going to Delhi'
sent1.split()
# Out:
# ['Hey', 'I', 'am', 'going', 'to', 'Delhi']

# %%
#sent tokenization
sent2="Hey I am new to this. Will you please help me out. How to do it?"
sent2.split('.')
# Out:
# ['Hey I am new to this', ' Will you please help me out', ' How to do it?']

# %%
#problems with slpit function
sent3="Hey, New Delhi is the capital of India!"
sent3.split()
# Out:
# ['Hey,', 'New', 'Delhi', 'is', 'the', 'capital', 'of', 'India!']

# %%
#problem
sent4="Hey can i have this? I do create one"
sent4.split('.')
# Out:
# ['Hey can i have this? I do create one']

# %% [markdown]
# **2. RegEx**

# %%
import re
sent5="I am going to Delhi!"
tokens=re.findall("[\w']+", sent5) #problem since we can't find the !, for that we need to find out different patterns
tokens
# Out:
# ['I', 'am', 'going', 'to', 'Delhi']

# %%
text=   """Chat abbreviations and slang have become a common part of online communication.
People use them to type faster and convey emotions or responses more efficiently.
For example, instead of writing “Be Right Back,” users often type “BRB.”
These short forms are especially popular in text messaging, social media, and gaming platforms?
Learning these abbreviations can help you understand conversations better and engage more naturally
in digital interactions. Whether you're chatting with friends or participating in online forums,
knowing these terms can make communication quicker and more fun """

sentences=re.compile('[.?\"] ').split(text)
sentences
# Out:
# ['Chat abbreviations and slang have become a common part of online communication.\nPeople use them to type faster and convey emotions or responses more efficiently.\nFor example, instead of writing “Be Right Back,” users often type “BRB.”\nThese short forms are especially popular in text messaging, social media, and gaming platforms?\nLearning these abbreviations can help you understand conversations better and engage more naturally\nin digital interactions',
#  "Whether you're chatting with friends or participating in online forums,\nknowing these terms can make communication quicker and more fun "]

# %% [markdown]
# **3. NLTK**

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
#word tokenization
sent1="I am going to Delhi!"
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'Delhi', '!']

# %%
sent6="I have a Ph.D in A.I."
sent7="We're here to help, please mail us @www.google.com"
sent8="A 5km ride cost $58.7"

# %%
word_tokenize(sent6)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I', '.']

# %%
word_tokenize(sent7) #some prblm
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  ',',
#  'please',
#  'mail',
#  'us',
#  '@',
#  'www.google.com']

# %%
word_tokenize(sent8) #some prblm
# Out:
# ['A', '5km', 'ride', 'cost', '$', '58.7']

# %%
dummy= "Python is one of the most popular programming languages. It’s simple to use, packed with features and supported by a wide range of libraries and frameworks. Its clean syntax makes it beginner-friendly."

# %%
dummy
# Out:
# 'Python is one of the most popular programming languages. It’s simple to use, packed with features and supported by a wide range of libraries and frameworks. Its clean syntax makes it beginner-friendly.'

# %%
#sentence tokenization
sents = sent_tokenize(dummy)
print(sents)
# Out:
# ['Python is one of the most popular programming languages.', 'It’s simple to use, packed with features and supported by a wide range of libraries and frameworks.', 'Its clean syntax makes it beginner-friendly.']

# %% [markdown]
# **4. SPACY**

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-9qwlk8sy\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=8.3.0,<8.4.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#        cwd: None
#   Complete output (355 lines):
#   Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython<3.0,>=0.25
#     Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting preshed<3.1.0,>=3.0.2
#     Using cached preshed-3.0.10.tar.gz (15 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-mwoxdw73\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0'
#          cwd: None
#     Complete output (75 lines):
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython>=0.28
#       Using cached cython-3.1.3-cp38-cp38-win_amd64.whl (2.7 MB)
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting murmurhash<1.1.0,>=0.28.0
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Building wheels for collected packages: cymem, murmurhash
#       Building wheel for cymem (PEP 517): started
#       Building wheel for cymem (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmpbdcx_zc3' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmptt04574g'
#            cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-n1jngjdm\cymem_7933a8cc7b734834989b4254d884b4d0
#       Complete output (15 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\cymem
#       copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#       creating build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for cymem
#       Building wheel for murmurhash (PEP 517): started
#       Building wheel for murmurhash (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmpkdostj84' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmpzp1bj78z'
#            cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-n1jngjdm\murmurhash_442c71cd24fe4f46a0c5df1ff8c96a14
#       Complete output (19 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for murmurhash
#     Failed to build cymem murmurhash
#     ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#     WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#     You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-mwoxdw73\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#     Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
#   Collecting murmurhash<1.1.0,>=0.28.0
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting thinc<8.4.0,>=8.3.0
#     Using cached thinc-8.3.2.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-33wqapq1\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (72 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\base_command.py", line 180, in _main
#         status = self.run(options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\req_command.py", line 204, in wrapper
#         return func(self, options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\commands\install.py", line 318, in run
#         requirement_set = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\resolver.py", line 127, in resolve
#         result = self._result = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 473, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 172, in _merge_into_criterion
#         if not criterion.candidates:
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\structs.py", line 139, in __bool__
#         return bool(self._sequence)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 129, in <genexpr>
#         return (c for c in iterator if id(c) not in self._incompatible_ids)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 33, in _iter_built
#         candidate = func()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\factory.py", line 200, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 306, in __init__
#         super().__init__(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 151, in __init__
#         self.dist = self._prepare()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 234, in _prepare
#         dist = self._prepare_distribution()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 317, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 570, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 59, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 138, in track
#         self.add(req)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 104, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#     You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/8a/9f/b2193b69dd112a46800182e897cda2fc9c497dfdd9352a0c5ba9252cf5f0/thinc-8.3.2.tar.gz#sha256=3e8ef69eac89a601e11d47fc9e43d26ffe7ef682dcf667c94ff35ff690549aeb (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-33wqapq1\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#     Using cached thinc-8.3.1.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-k0j3k0kw\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (72 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\base_command.py", line 180, in _main
#         status = self.run(options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\req_command.py", line 204, in wrapper
#         return func(self, options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\commands\install.py", line 318, in run
#         requirement_set = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\resolver.py", line 127, in resolve
#         result = self._result = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 473, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 172, in _merge_into_criterion
#         if not criterion.candidates:
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\structs.py", line 139, in __bool__
#         return bool(self._sequence)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 129, in <genexpr>
#         return (c for c in iterator if id(c) not in self._incompatible_ids)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 33, in _iter_built
#         candidate = func()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\factory.py", line 200, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 306, in __init__
#         super().__init__(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 151, in __init__
#         self.dist = self._prepare()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 234, in _prepare
#         dist = self._prepare_distribution()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 317, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 570, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 59, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 138, in track
#         self.add(req)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 104, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#     You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/ea/60/b7d645d621a47d649975b53c13cdf3e66b456a24727ccd34794f1014f45c/thinc-8.3.1.tar.gz#sha256=44e747bbf93e981dfded7d432b68ef1ba75b28ef46fc51f185477970743b36e9 (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-k0j3k0kw\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#     Using cached thinc-8.3.0.tar.gz (193 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 2:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-ba4h_nbn\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"''
#          cwd: None
#     Complete output (72 lines):
#     Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython<3.0,>=0.25
#       Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#     Collecting murmurhash<1.1.0,>=1.0.2
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting preshed<3.1.0,>=3.0.2
#       Using cached preshed-3.0.10.tar.gz (15 kB)
#     ERROR: Exception:
#     Traceback (most recent call last):
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\base_command.py", line 180, in _main
#         status = self.run(options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\cli\req_command.py", line 204, in wrapper
#         return func(self, options, args)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\commands\install.py", line 318, in run
#         requirement_set = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\resolver.py", line 127, in resolve
#         result = self._result = resolver.resolve(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 473, in resolve
#         state = resolution.resolve(requirements, max_rounds=max_rounds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#         name, crit = self._merge_into_criterion(r, parent=None)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\resolvers.py", line 172, in _merge_into_criterion
#         if not criterion.candidates:
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_vendor\resolvelib\structs.py", line 139, in __bool__
#         return bool(self._sequence)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#         return any(self)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 129, in <genexpr>
#         return (c for c in iterator if id(c) not in self._incompatible_ids)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\found_candidates.py", line 33, in _iter_built
#         candidate = func()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\factory.py", line 200, in _make_candidate_from_link
#         self._link_candidate_cache[link] = LinkCandidate(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 306, in __init__
#         super().__init__(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 151, in __init__
#         self.dist = self._prepare()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 234, in _prepare
#         dist = self._prepare_distribution()
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\resolution\resolvelib\candidates.py", line 317, in _prepare_distribution
#         return self._factory.preparer.prepare_linked_requirement(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#         return self._prepare_linked_requirement(req, parallel_builds)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 570, in _prepare_linked_requirement
#         dist = _get_prepared_distribution(
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\operations\prepare.py", line 59, in _get_prepared_distribution
#         with req_tracker.track(req):
#       File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.8_3.8.2800.0_x64__qbz5n2kfra8p0\lib\contextlib.py", line 113, in __enter__
#         return next(self.gen)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 138, in track
#         self.add(req)
#       File "C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip\_internal\req\req_tracker.py", line 104, in add
#         raise LookupError(message)
#     LookupError: https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6) is already being built: preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff
#     WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#     You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/15/0a/250f7fa34632616bb4fc37decbc46ed09243bade708968dc869d8a4c144b/thinc-8.3.0.tar.gz#sha256=eb3bed54f5c00ec9addaaa208c51ccfa059483d73140cd515aa33373715c6e59 (from https://pypi.org/simple/thinc/) (requires-python:>=3.6). Command errored out with exit status 2: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-ba4h_nbn\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=1.0.0,<1.1.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#   ERROR: Could not find a version that satisfies the requirement thinc<8.4.0,>=8.3.0 (from versions: 1.0, 1.1, 1.2, 1.3, 1.4, 1.5, 1.41, 1.42, 1.60, 1.61, 1.62, 1.63, 1.64, 1.65, 1.66, 1.67, 1.68, 1.69, 1.70, 1.71, 1.72, 1.73, 1.74, 1.75, 1.76, 2.0, 3.0, 3.1, 3.2, 3.3, 3.4.1, 4.0.0, 4.1.0, 4.2.0, 5.0.0, 5.0.1, 5.0.2, 5.0.3, 5.0.4, 5.0.5, 5.0.6, 5.0.7, 5.0.8, 6.0.0, 6.1.0, 6.1.1, 6.1.2, 6.1.3, 6.2.0, 6.3.0, 6.4.0, 6.5.0, 6.5.2, 6.6.0, 6.7.0, 6.7.1, 6.7.2, 6.7.3, 6.8.0, 6.8.1, 6.8.2, 6.9.0, 6.10.0, 6.10.1.dev0, 6.10.1, 6.10.2.dev0, 6.10.2.dev1, 6.10.2, 6.10.3.dev0, 6.10.3.dev1, 6.10.3, 6.10.4.dev0, 6.11.0.dev2, 6.11.1.dev0, 6.11.1.dev1, 6.11.1.dev2, 6.11.1.dev3, 6.11.1.dev4, 6.11.1.dev6, 6.11.1.dev7, 6.11.1.dev10, 6.11.1.dev11, 6.11.1.dev12, 6.11.1.dev13, 6.11.1.dev15, 6.11.1.dev16, 6.11.1.dev17, 6.11.1.dev18, 6.11.1.dev19, 6.11.1.dev20, 6.11.1, 6.11.2.dev0, 6.11.2, 6.11.3.dev1, 6.11.3.dev2, 6.12.0, 6.12.1, 7.0.0.dev0, 7.0.0.dev1, 7.0.0.dev2, 7.0.0.dev3, 7.0.0.dev4, 7.0.0.dev5, 7.0.0.dev6, 7.0.0.dev8, 7.0.0, 7.0.1.dev0, 7.0.1.dev1, 7.0.1.dev2, 7.0.1, 7.0.2, 7.0.3, 7.0.4.dev0, 7.0.4, 7.0.5.dev0, 7.0.5, 7.0.6, 7.0.7, 7.0.8, 7.1.0.dev0, 7.1.0, 7.1.1, 7.2.0.dev3, 7.2.0, 7.3.0.dev0, 7.3.0, 7.3.1, 7.4.0.dev0, 7.4.0.dev1, 7.4.0.dev2, 7.4.0, 7.4.1, 7.4.2, 7.4.3, 7.4.4, 7.4.5, 7.4.6, 8.0.0.dev0, 8.0.0.dev2, 8.0.0.dev4, 8.0.0a0, 8.0.0a1, 8.0.0a2, 8.0.0a3, 8.0.0a6, 8.0.0a8, 8.0.0a9, 8.0.0a11, 8.0.0a12, 8.0.0a13, 8.0.0a14, 8.0.0a16, 8.0.0a17, 8.0.0a18, 8.0.0a19, 8.0.0a20, 8.0.0a21, 8.0.0a22, 8.0.0a23, 8.0.0a24, 8.0.0a25, 8.0.0a26, 8.0.0a27, 8.0.0a28, 8.0.0a29, 8.0.0a30, 8.0.0a31, 8.0.0a32, 8.0.0a33, 8.0.0a34, 8.0.0a35, 8.0.0a36, 8.0.0a40, 8.0.0a41, 8.0.0a42, 8.0.0a43, 8.0.0a44, 8.0.0rc0, 8.0.0rc1, 8.0.0rc2, 8.0.0rc3, 8.0.0rc4, 8.0.0rc5, 8.0.0rc6.dev0, 8.0.0rc6, 8.0.0, 8.0.1, 8.0.2, 8.0.3, 8.0.4, 8.0.5, 8.0.6, 8.0.7, 8.0.8, 8.0.9, 8.0.10, 8.0.11, 8.0.12, 8.0.13, 8.0.14.dev0, 8.0.14, 8.0.15, 8.0.16, 8.0.17, 8.1.0.dev0, 8.1.0.dev1, 8.1.0.dev2, 8.1.0.dev3, 8.1.0, 8.1.1, 8.1.2, 8.1.3, 8.1.4, 8.1.5, 8.1.6, 8.1.7, 8.1.8, 8.1.9, 8.1.10, 8.1.11, 8.1.12, 8.2.0, 8.2.1, 8.2.2, 8.2.3, 8.2.4, 8.2.5, 8.3.0, 8.3.1, 8.3.2, 9.0.0.dev0, 9.0.0.dev1, 9.0.0.dev2, 9.0.0.dev3, 9.0.0.dev4, 9.0.0.dev5)
#   ERROR: No matching distribution found for thinc<8.4.0,>=8.3.0
#   WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#   You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/07/53/536941af8fbb5cb10a778f0dbd2a17b0f13e7ebfc11e67b154be60508fdf/spacy-3.8.2.tar.gz#sha256=4b37ebd25ada4059b0dc9e0893e70dde5df83485329a068ef04580e70892a65d (from https://pypi.org/simple/spacy/) (requires-python:>=3.7). Command errored out with exit status 1: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-71496hju\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-9qwlk8sy\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=8.3.0,<8.4.0' 'numpy>=2.0.0,<2.1.0; python_version < '"'"'3.9'"'"'' 'numpy>=2.0.0,<2.1.0; python_version >= '"'"'3.9'"'"'' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-ljcdizv0\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-0t43aa_b\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.25,<3.0' 'murmurhash>=1.0.2,<1.1.0' 'cymem>=2.0.2,<2.1.0' 'preshed>=3.0.2,<3.1.0' 'blis>=0.7.8,<0.8.0' 'numpy>=1.15.0,<2.0.0; python_version < '"'"'3.9'"'"'' 'numpy>=1.25.0,<2.0.0; python_version >= '"'"'3.9'"'"''
#        cwd: None
#   Complete output (166 lines):
#   Ignoring numpy: markers 'python_version >= "3.9"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython<3.0,>=0.25
#     Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#   Collecting murmurhash<1.1.0,>=1.0.2
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting preshed<3.1.0,>=3.0.2
#     Using cached preshed-3.0.10.tar.gz (15 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-ljcdizv0\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-nwo2x2ns\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0'
#          cwd: None
#     Complete output (75 lines):
#     Collecting setuptools
#       Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#     Collecting cython>=0.28
#       Using cached cython-3.1.3-cp38-cp38-win_amd64.whl (2.7 MB)
#     Collecting cymem<2.1.0,>=2.0.2
#       Using cached cymem-2.0.11.tar.gz (10 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Collecting murmurhash<1.1.0,>=0.28.0
#       Using cached murmurhash-1.0.13.tar.gz (13 kB)
#       Installing build dependencies: started
#       Installing build dependencies: finished with status 'done'
#       Getting requirements to build wheel: started
#       Getting requirements to build wheel: finished with status 'done'
#         Preparing wheel metadata: started
#         Preparing wheel metadata: finished with status 'done'
#     Building wheels for collected packages: cymem, murmurhash
#       Building wheel for cymem (PEP 517): started
#       Building wheel for cymem (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmp347oggxi' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmp7kkrpaom'
#            cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-bhm16qjs\cymem_d580a5fd950a4397b41b4fd7a57046d1
#       Complete output (15 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\cymem
#       copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#       creating build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#       copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#       copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#       running build_ext
#       building 'cymem.cymem' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for cymem
#       Building wheel for murmurhash (PEP 517): started
#       Building wheel for murmurhash (PEP 517): finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmp78kjaroi' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmp0joq4r6g'
#            cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-bhm16qjs\murmurhash_dea68bc03c07440caf7275dd50b7bf59
#       Complete output (19 lines):
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#       copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#       creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#       running build_ext
#       building 'murmurhash.mrmr' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#       ERROR: Failed building wheel for murmurhash
#     Failed to build cymem murmurhash
#     ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#     WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#     You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#     ----------------------------------------
#   WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-ljcdizv0\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-nwo2x2ns\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#     Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
#   Collecting blis<0.8.0,>=0.7.8
#     Using cached blis-0.7.11-cp38-cp38-win_amd64.whl (6.6 MB)
#   Collecting numpy<2.0.0,>=1.15.0
#     Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#   Building wheels for collected packages: murmurhash, cymem
#     Building wheel for murmurhash (PEP 517): started
#     Building wheel for murmurhash (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmp1j99mk8e' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmps1_0p5is'
#          cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-g5vx02ps\murmurhash_ecde85e1a8d143f89894f8bea2c0caae
#     Complete output (19 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     running build_ext
#     building 'murmurhash.mrmr' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
# ...
#        cwd: None
#   Complete output (75 lines):
#   Collecting setuptools
#     Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#   Collecting cython>=0.28
#     Using cached cython-3.1.3-cp38-cp38-win_amd64.whl (2.7 MB)
#   Collecting cymem<2.1.0,>=2.0.2
#     Using cached cymem-2.0.11.tar.gz (10 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Collecting murmurhash<1.1.0,>=0.28.0
#     Using cached murmurhash-1.0.13.tar.gz (13 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#       Preparing wheel metadata: started
#       Preparing wheel metadata: finished with status 'done'
#   Building wheels for collected packages: cymem, murmurhash
#     Building wheel for cymem (PEP 517): started
#     Building wheel for cymem (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmp9xmi08uw' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmpz5o47qvc'
#          cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-1s3m5r5a\cymem_ac1814b1acaf4b8c956e0885006feed9
#     Complete output (15 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\cymem
#     copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#     creating build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#     copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#     copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#     running build_ext
#     building 'cymem.cymem' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for cymem
#     Building wheel for murmurhash (PEP 517): started
#     Building wheel for murmurhash (PEP 517): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\tmpilas7fkh' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmp33xjneo0'
#          cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-1s3m5r5a\murmurhash_657f9670c93748878e7b36c80a8c2e05
#     Complete output (19 lines):
#     running bdist_wheel
#     running build
#     running build_py
#     creating build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#     copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#     creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#     running build_ext
#     building 'murmurhash.mrmr' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for murmurhash
#   Failed to build cymem murmurhash
#   ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
#   WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
#   You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4d/3a/db814f67a05b6d7f9c15d38edef5ec9b21415710705b393883de92aee5ef/preshed-3.0.10.tar.gz#sha256=5a5c8e685e941f4ffec97f1fbf32694b8107858891a4bc34107fac981d8296ff (from https://pypi.org/simple/preshed/) (requires-python:<3.14,>=3.6). Command errored out with exit status 1: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'C:\Users\gupta\AppData\Local\Temp\pip-standalone-pip-0nrxsu7q\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\gupta\AppData\Local\Temp\pip-build-env-pg8ditnn\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'cython>=0.28' 'cymem>=2.0.2,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmpefc4cvt4'
#        cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-dodkyp_p\cymem_2beb8df248134eee807a336f23daa2a3
#   Complete output (15 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-38\cymem
#   copying cymem\about.py -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\__init__.py -> build\lib.win-amd64-cpython-38\cymem
#   creating build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\tests\test_import.py -> build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\tests\__init__.py -> build\lib.win-amd64-cpython-38\cymem\tests
#   copying cymem\cymem.pyx -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\cymem.pxd -> build\lib.win-amd64-cpython-38\cymem
#   copying cymem\__init__.pxd -> build\lib.win-amd64-cpython-38\cymem
#   running build_ext
#   building 'cymem.cymem' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for cymem
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe' 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\gupta\AppData\Local\Temp\tmp73shr2h7'
#        cwd: C:\Users\gupta\AppData\Local\Temp\pip-install-dodkyp_p\murmurhash_4f5bba3a278f4b8788fbf4f511725a6e
#   Complete output (19 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\about.py -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash
#   creating build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\test_hash.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\test_import.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\tests\__init__.py -> build\lib.win-amd64-cpython-38\murmurhash\tests
#   copying murmurhash\mrmr.pyx -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\mrmr.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#   copying murmurhash\__init__.pxd -> build\lib.win-amd64-cpython-38\murmurhash
#   creating build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-cpython-38\murmurhash\include\murmurhash
#   running build_ext
#   building 'murmurhash.mrmr' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for murmurhash
# ERROR: Could not build wheels for cymem, murmurhash which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\gupta\Desktop\NLP Lab complete code\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Collecting spacy
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Using cached spacy-3.7.5-cp38-cp38-win_amd64.whl (12.5 MB)
# Collecting weasel<0.5.0,>=0.1.0
#   Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: setuptools in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from spacy) (56.0.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.4.1-py3-none-any.whl (182 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from spacy) (1.24.4)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting typer<1.0.0,>=0.3.0
#   Using cached typer-0.16.1-py3-none-any.whl (46 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from spacy) (2.32.4)
# Collecting thinc<8.3.0,>=8.2.2
#   Using cached thinc-8.2.5.tar.gz (193 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   Using cached thinc-8.2.4-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.10.tar.gz (15 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.8-cp38-cp38-win_amd64.whl (483 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.13.tar.gz (13 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: packaging>=20.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from spacy) (25.0)
# Collecting language-data>=1.2
#   Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Collecting marisa-trie>=1.1.0
#   Using cached marisa_trie-1.2.1-cp38-cp38-win_amd64.whl (152 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Collecting pydantic-core==2.27.2
#   Using cached pydantic_core-2.27.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.8.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.11-cp38-cp38-win_amd64.whl (6.6 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Using cached rich-14.1.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gupta\desktop\nlp lab complete code\venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Using cached cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Collecting smart-open<8.0.0,>=5.2.1
#   Using cached smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Collecting wrapt
#   Using cached wrapt-1.17.3-cp38-cp38-win_amd64.whl (38 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (PEP 517): started
#   Building wheel for cymem (PEP 517): finished with status 'error'
#   Building wheel for murmurhash (PEP 517): started
#   Building wheel for murmurhash (PEP 517): finished with status 'error'
# Failed to build cymem murmurhash

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 import spacy
#       2 nlp=spacy.load('en_core_web_sm')
#
# ModuleNotFoundError: No module named 'spacy'

# %%
doc1=nlp(sent6)
doc2=nlp(sent7)
doc3=nlp(sent8)

# %%
for token in doc3: #performing a bit better than nltk
    print(token)
# Out:
# A
# 5
# km
# ride
# cost
# $
# 58.7

# %% [markdown]
# **iii. Stop Words Removal**

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
stopwords.words('french')
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
#  'fus',
#  'fut',
#  'fûmes',
#  'fûtes',
#  'furent',
#  'sois',
#  'soit',
#  'soyons',
#  'soyez',
#  'soient',
#  'fusse',
#  'fusses',
#  'fût',
#  'fussions',
#  'fussiez',
#  'fussent',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'eu',
#  'eue',
#  'eues',
#  'eus',
#  'ai',
#  'as',
#  'avons',
#  'avez',
#  'ont',
#  'aurai',
#  'auras',
#  'aura',
#  'aurons',
#  'aurez',
#  'auront',
#  'aurais',
#  'aurait',
#  'aurions',
#  'auriez',
#  'auraient',
#  'avais',
#  'avait',
#  'avions',
#  'aviez',
#  'avaient',
#  'eut',
#  'eûmes',
#  'eûtes',
#  'eurent',
#  'aie',
#  'aies',
#  'ait',
#  'ayons',
#  'ayez',
#  'aient',
#  'eusse',
#  'eusses',
#  'eût',
#  'eussions',
#  'eussiez',
#  'eussent']

# %%
def remove_stopwords(text):
    new_text=[]

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append(' ')
        else:
            new_text.append(word)
    x=new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
remove_stopwords('this is how we make students learn in the class these things are mandatory for one to have')
# Out:
# '        make students learn     class   things   mandatory   one    '

# %% [markdown]
# **iv. Chat Conversation**

# %%
chat_words = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "A3": "Anytime, Anywhere, Anyplace",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRT": "Be Right There",
    "BTW": "By The Way",
    "B4": "Before",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "FAQ": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FWIW": "For What It's Worth",
    "FYI": "For Your Information",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GN": "Good Night",
    "GMTA": "Great Minds Think Alike",
    "GR8": "Great!",
    "G9": "Genius",
    "IC": "I See",
    "ICQ": "I Seek you (also a chat program)",
    "ILU": "I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "KISS": "Keep It Simple, Stupid",
    "LDR": "Long Distance Relationship",
    "LMAO": "Laughing my a** off",
    "LOL": "Laughing out loud",
    "LTNS": "Long Time No See",
    "L8R": "Later",
    "MTE": "My Thoughts Exactly",
    "M8": "Mate",
    "NRN": "No Reply Necessary",
    "OIC": "Oh I See",
    "PITA": "Pain In The A..",
    "PRT": "Party",
    "PRW": "Parents Are Watching",
    "QPSA?": "Que Pasa?",
    "ROFL": "Rolling On The Floor Laughing",
    "ROFLOL": "Rolling On The Floor Laughing Out Loud",
    "ROTFLMAO": "Rolling On The Floor Laughing My A.. Off",
    "SK8": "Skate",
    "STATS": "Your sex and age",
    "ASL": "Age, Sex, Location",
    "THX": "Thank You",
    "TTFN": "Ta-Ta For Now!",
    "TTYL": "Talk To You Later",
    "U": "You",
    "U2": "You Too",
    "U4E": "Yours For Ever",
    "WB": "Welcome Back",
    "WTF": "What The F...",
    "WTG": "Way To Go!",
    "WUF": "Where Are You From?",
    "W8": "Wait...",
    "7K": "Sick:-D Laugher",
    "TFW": "That feeling when",
    "MFW": "My face when",
    "MRW": "My reaction when",
    "IFYP": "I feel your pain",
    "TNTL": "Trying not to laugh",
    "JK": "Just kidding",
    "IDC": "I don’t care",
    "ILY": "I love you",
    "IMU": "I miss you",
    "ADIH": "Another day in hell",
    "ZZZ": "Sleeping, bored, tired",
    "WYWH": "Wish you were here",
    "TIME": "Tears in my eyes",
    "BAE": "Before anyone else",
    "FIMH": "Forever in my heart",
    "BSAAW": "Big smile and a wink",
    "BWL": "Bursting with laughter",
    "BFF": "Best friends forever",
    "CSL": "Can’t stop laughing"
}

# %%
def chat_conv(text):
    new_text=[]
    for w in text.split():
        if w.upper() in chat_words:
            new_text.append(chat_words[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
chat_conv("AFAIK He is the best guy.")
# Out:
# 'As Far As I Know He is the best guy.'

# %% [markdown]
# **v. Stemming/Lemmatization**

# %%
#Stemming: extracts the root of the word but not ensures that root word is a part of English language or dictionary
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
sample="walking walked walks walk"

# %%
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text="The children were playing in the garden while their mother was cooking. She enjoys gardening and often gardens on weekends. The players played with great enthusiasm, hoping to impress the coaches. Some were running, others had run earlier, and a few enjoyed the run thoroughly. He studies daily, studied last night, and is currently studying math. They happily agreed to the agreement after arguing about the argument."
print(text)
# Out:
# The children were playing in the garden while their mother was cooking. She enjoys gardening and often gardens on weekends. The players played with great enthusiasm, hoping to impress the coaches. Some were running, others had run earlier, and a few enjoyed the run thoroughly. He studies daily, studied last night, and is currently studying math. They happily agreed to the agreement after arguing about the argument.

# %%
stem_words(text) # some prblm is their since its giving the root word that is not excatly the root word
# Out:
# 'the children were play in the garden while their mother wa cooking. she enjoy garden and often garden on weekends. the player play with great enthusiasm, hope to impress the coaches. some were running, other had run earlier, and a few enjoy the run thoroughly. he studi daily, studi last night, and is current studi math. they happili agre to the agreement after argu about the argument.'

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Lemmatization: Ensures the root word is a part of English language or dictionary
import nltk
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer= WordNetLemmatizer()

sentence="He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun"
punctuations="?:!.,;"
sentence_words=nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)

sentence_words
print("{0:20} {1:20}". format("Word", "Lemma"))
for word in sentence_words:
    print("{0:20} {1:20}".format(word, wordnet_lemmatizer.lemmatize(word, pos='v'))) #need to specify pos
# Out:
# Word                 Lemma
# He                   He
# was                  be
# running              run
# and                  and
# eating               eat
# at                   at
# same                 same
# time                 time
# He                   He
# has                  have
# bad                  bad
# habit                habit
# of                   of
# swimming             swim
# after                after
# playing              play
# long                 long
# hours                hours
# in                   in
# the                  the
# Sun                  Sun

# %% [markdown]
# **vi. Language Detection**

# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.11/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)

# %%
text_clean2 = "La película fue absolutamente fantástica y agradable"

# %%
from langdetect import detect, detect_langs

def detect_language(text):
    try:
        lang = detect(text)
        lang_prob = detect_langs(text)
        return lang, lang_prob
    except Exception as e:
        return "Error", str(e)

# %%
# Example usage
text_clean2 = "La película fue absolutamente fantástica y agradable"
lang_code, lang_probs = detect_language(text_clean2)

print("Text:", text_clean2)
print("Detected Language Code:", lang_code)
print("Confidence:", lang_probs) #es-Spanish
# Out:
# Text: La película fue absolutamente fantástica y agradable
# Detected Language Code: es
# Confidence: [es:0.999995932581196]

# %% [markdown]
# #c. ADVANCED PREPROCESSING
#
# **i. POS Tagging**

# %%
text_adv1 = "The quick brown fox jumps over the lazy dog"

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def pos_tag_text(text):
    tokens = nltk.word_tokenize(text)
    tagged = nltk.pos_tag(tokens)
    return tagged
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Example usage
text_adv1 = "The quick brown fox jumps over the lazy dog"
pos_tags = pos_tag_text(text_adv1)

print("Text:", text_adv1)
print("POS Tags:", pos_tags) #DT-Determiner, JJ-Adjective, NN-Noun, VBZ-Verb (3rd person singular), IN-Preposition
# Out:
# Text: The quick brown fox jumps over the lazy dog
# POS Tags: [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN')]

# %% [markdown]
# **ii. Parsing**

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 46.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2025.7.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en_core_web_sm 3.8.0
#     Uninstalling en_core_web_sm-3.8.0:
#       Successfully uninstalled en_core_web_sm-3.8.0
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
text_adv2 = "The quick brown fox jumps over the lazy dog"

# %%
import spacy

# Load English language model
nlp = spacy.load("en_core_web_sm")

def parse_sentence(text):
    doc = nlp(text)
    for token in doc:
        print(f"{token.text:<12} {token.dep_:<10} {token.head.text:<10} {token.pos_:<6}")

# %%
# Example usage
text_adv2 = "The quick brown fox jumps over the lazy dog"
print("Parsed Tokens:")
parse_sentence(text_adv2) #nsubj: nominal subject of the verb, ROOT: main verb of the sentence, amod: adjective modifier, pobj: object of a preposition, det: determiner
# Out:
# Parsed Tokens:
# The          det        fox        DET
# quick        amod       fox        ADJ
# brown        amod       fox        ADJ
# fox          nsubj      jumps      NOUN
# jumps        ROOT       jumps      VERB
# over         prep       jumps      ADP
# the          det        dog        DET
# lazy         amod       dog        ADJ
# dog          pobj       over       NOUN

# %% [markdown]
# **iii. Coreference Resolution**
